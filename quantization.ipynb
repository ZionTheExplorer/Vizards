# %%
import os
import random
import tensorflow as tf
import cv2
import numpy as np
import time
import csv
import glob
import shutil
import sys
from PIL import Image
import matplotlib.pyplot as plt
from sklearn.model_selection import KFold
from tensorflow.python.framework import ops
from tensorflow.python.framework import dtypes
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, Flatten, Dropout, MaxPooling2D, BatchNormalization, Activation
from tensorflow.keras.models import model_from_json
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.python.keras.utils.generic_utils import custom_object_scope
import tensorflow_model_optimization as tfmot
from tensorflow_model_optimization.python.core.quantization.keras import quantize_config
from tensorflow_model_optimization.python.core.quantization.keras import quantizers

Thepath = "/Users/george/Desktop/ck+/Images"

LastValueQuantizer = tfmot.quantization.keras.quantizers.LastValueQuantizer
MovingAverageQuantizer = tfmot.quantization.keras.quantizers.MovingAverageQuantizer
quantize_annotate_layer = tfmot.quantization.keras.quantize_annotate_layer
quantize_annotate_model = tfmot.quantization.keras.quantize_annotate_model
quantize_scope = tfmot.quantization.keras.quantize_scope

conv2d=3
conv2d_1=3
conv2d_2=3
activ=3
activ_1=3
activ_2=3
maxpool=3
maxpool_1=3
maxpool_2=3
flatten=2
dropout=2
dense=4
dense_1=2

#QuantizerClasses
class DefaultConv2DQuantizeConfig(tfmot.quantization.keras.QuantizeConfig):
    def get_weights_and_quantizers(self, layer):
        return [(layer.weights[i], MovingAverageQuantizer(num_bits=8, symmetric=True, narrow_range=False, per_axis=False))for i in range(0)]
     
    def get_activations_and_quantizers(self, layer):
        return [(layer.activation, MovingAverageQuantizer(num_bits=8, symmetric=False, narrow_range=False, per_axis=False))]

    def set_quantize_weights(self, layer, quantize_weights):
        [(layer.weights[i] == quantize_weights[0]) for i in range(0)]
        
    def set_quantize_activations(self, layer, quantize_activations):
        layer.activation = quantize_activations[0]

    def get_output_quantizers(self, layer):
        return [quantizers.MovingAverageQuantizer(num_bits=8, per_axis=False, symmetric=False, narrow_range=False)]

    def get_config(self):
        return {}
       
class DefaultActivationQuantizeConfig(tfmot.quantization.keras.QuantizeConfig):
    def get_weights_and_quantizers(self, layer):
        return []
        
    def get_activations_and_quantizers(self, layer):
        return [(layer.activation, MovingAverageQuantizer(num_bits=8, symmetric=False, narrow_range=False, per_axis=False))]

    def set_quantize_weights(self, layer, quantize_weights):
        pass
        
    def set_quantize_activations(self, layer, quantize_activations):
        pass

    def get_output_quantizers(self, layer):
        return [quantizers.MovingAverageQuantizer(num_bits=8, per_axis=False, symmetric=False, narrow_range=False)]

    def get_config(self):
        return {}
    
class DefaultMaxPool2DQuantizeConfig(tfmot.quantization.keras.QuantizeConfig):
    def get_weights_and_quantizers(self, layer):
        return []
        
    def get_activations_and_quantizers(self, layer):
        return []

    def set_quantize_weights(self, layer, quantize_weights):
        pass
        
    def set_quantize_activations(self, layer, quantize_activations):
        pass

    def get_output_quantizers(self, layer):
        return [quantizers.MovingAverageQuantizer(num_bits=8, per_axis=False, symmetric=False, narrow_range=False)]

    def get_config(self):
        return {}    

class DefaultFlattenQuantizeConfig(tfmot.quantization.keras.QuantizeConfig):
    def get_weights_and_quantizers(self, layer):
        return []
        
    def get_activations_and_quantizers(self, layer):
        return []

    def set_quantize_weights(self, layer, quantize_weights):
        pass
        
    def set_quantize_activations(self, layer, quantize_activations):
        pass

    def get_output_quantizers(self, layer):
        return [quantizers.MovingAverageQuantizer(num_bits=8, per_axis=False, symmetric=False, narrow_range=False)]

    def get_config(self):
        return {}
    
class DefaultDropoutQuantizeConfig(tfmot.quantization.keras.QuantizeConfig):
    def get_weights_and_quantizers(self, layer):
        return []
        
    def get_activations_and_quantizers(self, layer):
        return []

    def set_quantize_weights(self, layer, quantize_weights):
        pass
        
    def set_quantize_activations(self, layer, quantize_activations):
        pass

    def get_output_quantizers(self, layer):
        return [quantizers.MovingAverageQuantizer(num_bits=8, per_axis=False, symmetric=False, narrow_range=False)]

    def get_config(self):
        return {} 
    
class DefaultDenseQuantizeConfig(tfmot.quantization.keras.QuantizeConfig):
    def get_weights_and_quantizers(self, layer):
        return [(layer.kernel, MovingAverageQuantizer(num_bits=8, symmetric=True, narrow_range=False, per_axis=False))]
     
    def get_activations_and_quantizers(self, layer):
        return [(layer.activation, MovingAverageQuantizer(num_bits=8, symmetric=False, narrow_range=False, per_axis=False))]

    def set_quantize_weights(self, layer, quantize_weights):
        layer.kernel = quantize_weights[0]
        
    def set_quantize_activations(self, layer, quantize_activations):
        layer.activation = quantize_activations[0]

    def get_output_quantizers(self, layer):
        return [quantizers.MovingAverageQuantizer(num_bits=8, per_axis=False, symmetric=False, narrow_range=False)]

    def get_config(self):
        return {}
    
#ModifiedConv2DQuantizerClasses
class ModifiedConv2DQuantizeConfig(DefaultConv2DQuantizeConfig):
    def get_weights_and_quantizers(self, layer):
        return [(layer.weights[i], MovingAverageQuantizer(num_bits=conv2d, symmetric=True, narrow_range=False, per_axis=False))for i in range(0)]
    def get_activations_and_quantizers(self, layer):
        return [(layer.activation, MovingAverageQuantizer(num_bits=conv2d, symmetric=False, narrow_range=False, per_axis=False))]
    def get_output_quantizers(self, layer):
        return [quantizers.MovingAverageQuantizer(num_bits=conv2d, per_axis=False, symmetric=False, narrow_range=False)]
    
class ModifiedConv2D_1QuantizeConfig(DefaultConv2DQuantizeConfig):
    def get_weights_and_quantizers(self, layer):
        return [(layer.weights[i], MovingAverageQuantizer(num_bits=conv2d_1, symmetric=True, narrow_range=False, per_axis=False))for i in range(0)]
    def get_activations_and_quantizers(self, layer):
        return [(layer.activation, MovingAverageQuantizer(num_bits=conv2d_1, symmetric=False, narrow_range=False, per_axis=False))]
    def get_output_quantizers(self, layer):
        return [quantizers.MovingAverageQuantizer(num_bits=conv2d_1, per_axis=False, symmetric=False, narrow_range=False)]
    
class ModifiedConv2D_2QuantizeConfig(DefaultConv2DQuantizeConfig):
    def get_weights_and_quantizers(self, layer):
        return [(layer.weights[i], MovingAverageQuantizer(num_bits=conv2d_2, symmetric=True, narrow_range=False, per_axis=False))for i in range(0)]
    def get_activations_and_quantizers(self, layer):
        return [(layer.activation, MovingAverageQuantizer(num_bits=conv2d_2, symmetric=False, narrow_range=False, per_axis=False))]
    def get_output_quantizers(self, layer):
        return [quantizers.MovingAverageQuantizer(num_bits=conv2d_2, per_axis=False, symmetric=False, narrow_range=False)]
    
#ModifiedActivationQuantizerClasses    
class ModifiedActivationQuantizeConfig(DefaultActivationQuantizeConfig):
    def get_activations_and_quantizers(self, layer):
        return [(layer.activation, MovingAverageQuantizer(num_bits=activ, symmetric=False, narrow_range=False, per_axis=False))]
    def get_output_quantizers(self, layer):
        return [quantizers.MovingAverageQuantizer(num_bits=activ, per_axis=False, symmetric=False, narrow_range=False)]
    
class ModifiedActivation_1QuantizeConfig(DefaultActivationQuantizeConfig):
    def get_activations_and_quantizers(self, layer):
        return [(layer.activation, MovingAverageQuantizer(num_bits=activ_1, symmetric=False, narrow_range=False, per_axis=False))]
    def get_output_quantizers(self, layer):
        return [quantizers.MovingAverageQuantizer(num_bits=activ_1, per_axis=False, symmetric=False, narrow_range=False)]

class ModifiedActivation_2QuantizeConfig(DefaultActivationQuantizeConfig):
    def get_activations_and_quantizers(self, layer):
        return [(layer.activation, MovingAverageQuantizer(num_bits=activ_2, symmetric=False, narrow_range=False, per_axis=False))]
    def get_output_quantizers(self, layer):
        return [quantizers.MovingAverageQuantizer(num_bits=activ_2, per_axis=False, symmetric=False, narrow_range=False)]
    
#ModifiedMaxPool2DQuantizerClasses 
class ModifiedMaxPool2DQuantizeConfig(DefaultMaxPool2DQuantizeConfig):
    def get_output_quantizers(self, layer):
        return [quantizers.MovingAverageQuantizer(num_bits=maxpool, per_axis=False, symmetric=False, narrow_range=False)]
    
class ModifiedMaxPool2D_1QuantizeConfig(DefaultMaxPool2DQuantizeConfig):
    def get_output_quantizers(self, layer):
        return [quantizers.MovingAverageQuantizer(num_bits=maxpool_1, per_axis=False, symmetric=False, narrow_range=False)]
    
class ModifiedMaxPool2D_2QuantizeConfig(DefaultMaxPool2DQuantizeConfig):
    def get_output_quantizers(self, layer):
        return [quantizers.MovingAverageQuantizer(num_bits=maxpool_2, per_axis=False, symmetric=False, narrow_range=False)]
    
#ModifiedFlattenQuantizerClasses     
class ModifiedFlattenQuantizeConfig(DefaultFlattenQuantizeConfig):
    def get_output_quantizers(self, layer):
        return [quantizers.MovingAverageQuantizer(num_bits=flatten, per_axis=False, symmetric=False, narrow_range=False)]
    
#ModifiedDropoutQuantizerClasses     
class ModifiedDropoutQuantizeConfig(DefaultDropoutQuantizeConfig):
    def get_output_quantizers(self, layer):
        return [quantizers.MovingAverageQuantizer(num_bits=dropout, per_axis=False, symmetric=False, narrow_range=False)]   

#ModifiedDenseQuantizerClasses     
class ModifiedDenseQuantizeConfig(DefaultDenseQuantizeConfig):
    def get_activations_and_quantizers(self, layer):
        return [(layer.activation, MovingAverageQuantizer(num_bits=dense, symmetric=False, narrow_range=False, per_axis=False))]
    def get_weights_and_quantizers(self, layer):
        return [(layer.kernel, MovingAverageQuantizer(num_bits=dense, symmetric=True, narrow_range=False, per_axis=False))]    
    def get_output_quantizers(self, layer):
        return [quantizers.MovingAverageQuantizer(num_bits=dense, per_axis=False, symmetric=False, narrow_range=False)]
    
class ModifiedDense_1QuantizeConfig(DefaultDenseQuantizeConfig):
    def get_activations_and_quantizers(self, layer):
        return [(layer.activation, MovingAverageQuantizer(num_bits=dense_1, symmetric=False, narrow_range=False, per_axis=False))]
    def get_weights_and_quantizers(self, layer):
        return [(layer.kernel, MovingAverageQuantizer(num_bits=dense_1, symmetric=True, narrow_range=False, per_axis=False))]    
    def get_output_quantizers(self, layer):
        return [quantizers.MovingAverageQuantizer(num_bits=dense_1, per_axis=False, symmetric=False, narrow_range=False)]    
    

#FunctionsForAnnotation    
def apply_quantization_to_layer_Conv2D(layer):
    if isinstance(layer, tf.keras.layers.Conv2D):
        if layer.name == "conv2d":
            return quantize_annotate_layer(layer, ModifiedConv2DQuantizeConfig())
        if layer.name == "conv2d_1":
            return quantize_annotate_layer(layer, ModifiedConv2D_1QuantizeConfig())
        if layer.name == "conv2d_2":
            return quantize_annotate_layer(layer, ModifiedConv2D_2QuantizeConfig())
    return layer

def apply_quantization_to_layer_Activation(layer):
    if isinstance(layer, tf.keras.layers.Activation):
        if layer.name == "activation":
            return quantize_annotate_layer(layer, ModifiedActivationQuantizeConfig())
        if layer.name == "activation_1":
            return quantize_annotate_layer(layer, ModifiedActivation_1QuantizeConfig())
        if layer.name == "activation_2":
            return quantize_annotate_layer(layer, ModifiedActivation_2QuantizeConfig())
    return layer

def apply_quantization_to_layer_MaxPool2D(layer):
    if isinstance(layer, tf.keras.layers.MaxPool2D):
        if layer.name == "max_pooling2d":
            return quantize_annotate_layer(layer,ModifiedMaxPool2DQuantizeConfig())
        if layer.name == "max_pooling2d_1":
            return quantize_annotate_layer(layer, ModifiedMaxPool2D_1QuantizeConfig())
        if layer.name == "max_pooling2d_2":
            return quantize_annotate_layer(layer, ModifiedMaxPool2D_2QuantizeConfig())
    return layer

def apply_quantization_to_layer_Flatten(layer):
    if isinstance(layer, tf.keras.layers.Flatten):
        return quantize_annotate_layer(layer, ModifiedFlattenQuantizeConfig())
    return layer

def apply_quantization_to_layer_Dropout(layer):
    if isinstance(layer, tf.keras.layers.Dropout):
        return quantize_annotate_layer(layer, ModifiedDropoutQuantizeConfig())
    return layer

def apply_quantization_to_layer_Dense(layer):
    if isinstance(layer, tf.keras.layers.Dense):
        if layer.name == "dense":
            return quantize_annotate_layer(layer,ModifiedDenseQuantizeConfig())
        if layer.name == "dense_1":
            return quantize_annotate_layer(layer, ModifiedDense_1QuantizeConfig())
    return layer

#Loading pre-trained model
pre_trained_model = tf.keras.models.load_model("Masks.h5")

print (pre_trained_model.layers[0].name) 

pre_trained_model.summary()

#Quantizing Conv2D
annotated_model1= tf.keras.models.clone_model(
    pre_trained_model,
    clone_function=apply_quantization_to_layer_Conv2D,
) 

with quantize_scope({'ModifiedConv2DQuantizeConfig': ModifiedConv2DQuantizeConfig},
                    {'ModifiedConv2D_1QuantizeConfig': ModifiedConv2D_1QuantizeConfig},
                    {'ModifiedConv2D_2QuantizeConfig': ModifiedConv2D_2QuantizeConfig},
                    {'ModifiedActivationQuantizeConfig': ModifiedActivationQuantizeConfig},
                    {'ModifiedActivation_1QuantizeConfig': ModifiedActivation_1QuantizeConfig},
                    {'ModifiedActivation_2QuantizeConfig': ModifiedActivation_2QuantizeConfig},
                    {'ModifiedMaxPool2DQuantizeConfig': ModifiedMaxPool2DQuantizeConfig},
                    {'ModifiedMaxPool2D_1QuantizeConfig': ModifiedMaxPool2D_1QuantizeConfig},
                    {'ModifiedMaxPool2D_2QuantizeConfig': ModifiedMaxPool2D_2QuantizeConfig},
                    {'ModifiedFlattenQuantizeConfig': ModifiedFlattenQuantizeConfig},
                    {'ModifiedDropoutQuantizeConfig': ModifiedDropoutQuantizeConfig},
                    {'ModifiedDenseQuantizeConfig': ModifiedDenseQuantizeConfig},
                    {'ModifiedDense_1QuantizeConfig': ModifiedDense_1QuantizeConfig}):
    quant_aware_model = tfmot.quantization.keras.quantize_apply(annotated_model1)
    
#Quantizing Activation    
annotated_model2= tf.keras.models.clone_model(
    quant_aware_model,
    clone_function=apply_quantization_to_layer_Activation,
)     
    
with quantize_scope({'ModifiedConv2DQuantizeConfig': ModifiedConv2DQuantizeConfig},
                    {'ModifiedConv2D_1QuantizeConfig': ModifiedConv2D_1QuantizeConfig},
                    {'ModifiedConv2D_2QuantizeConfig': ModifiedConv2D_2QuantizeConfig},
                    {'ModifiedActivationQuantizeConfig': ModifiedActivationQuantizeConfig},
                    {'ModifiedActivation_1QuantizeConfig': ModifiedActivation_1QuantizeConfig},
                    {'ModifiedActivation_2QuantizeConfig': ModifiedActivation_2QuantizeConfig},
                    {'ModifiedMaxPool2DQuantizeConfig': ModifiedMaxPool2DQuantizeConfig},
                    {'ModifiedMaxPool2D_1QuantizeConfig': ModifiedMaxPool2D_1QuantizeConfig},
                    {'ModifiedMaxPool2D_2QuantizeConfig': ModifiedMaxPool2D_2QuantizeConfig},
                    {'ModifiedFlattenQuantizeConfig': ModifiedFlattenQuantizeConfig},
                    {'ModifiedDropoutQuantizeConfig': ModifiedDropoutQuantizeConfig},
                    {'ModifiedDenseQuantizeConfig': ModifiedDenseQuantizeConfig},
                    {'ModifiedDense_1QuantizeConfig': ModifiedDense_1QuantizeConfig}):
    quant_aware_model = tfmot.quantization.keras.quantize_apply(annotated_model2)
    
#Quantizing MaxPool2D   
annotated_model3= tf.keras.models.clone_model(
    quant_aware_model,
    clone_function=apply_quantization_to_layer_MaxPool2D,
)     
    
with quantize_scope({'ModifiedConv2DQuantizeConfig': ModifiedConv2DQuantizeConfig},
                    {'ModifiedConv2D_1QuantizeConfig': ModifiedConv2D_1QuantizeConfig},
                    {'ModifiedConv2D_2QuantizeConfig': ModifiedConv2D_2QuantizeConfig},
                    {'ModifiedActivationQuantizeConfig': ModifiedActivationQuantizeConfig},
                    {'ModifiedActivation_1QuantizeConfig': ModifiedActivation_1QuantizeConfig},
                    {'ModifiedActivation_2QuantizeConfig': ModifiedActivation_2QuantizeConfig},
                    {'ModifiedMaxPool2DQuantizeConfig': ModifiedMaxPool2DQuantizeConfig},
                    {'ModifiedMaxPool2D_1QuantizeConfig': ModifiedMaxPool2D_1QuantizeConfig},
                    {'ModifiedMaxPool2D_2QuantizeConfig': ModifiedMaxPool2D_2QuantizeConfig},
                    {'ModifiedFlattenQuantizeConfig': ModifiedFlattenQuantizeConfig},
                    {'ModifiedDropoutQuantizeConfig': ModifiedDropoutQuantizeConfig},
                    {'ModifiedDenseQuantizeConfig': ModifiedDenseQuantizeConfig},
                    {'ModifiedDense_1QuantizeConfig': ModifiedDense_1QuantizeConfig}):
    quant_aware_model = tfmot.quantization.keras.quantize_apply(annotated_model3) 
    
#Quantizing Flatten   
annotated_model4= tf.keras.models.clone_model(
    quant_aware_model,
    clone_function=apply_quantization_to_layer_Flatten,
)     
    
with quantize_scope({'ModifiedConv2DQuantizeConfig': ModifiedConv2DQuantizeConfig},
                    {'ModifiedConv2D_1QuantizeConfig': ModifiedConv2D_1QuantizeConfig},
                    {'ModifiedConv2D_2QuantizeConfig': ModifiedConv2D_2QuantizeConfig},
                    {'ModifiedActivationQuantizeConfig': ModifiedActivationQuantizeConfig},
                    {'ModifiedActivation_1QuantizeConfig': ModifiedActivation_1QuantizeConfig},
                    {'ModifiedActivation_2QuantizeConfig': ModifiedActivation_2QuantizeConfig},
                    {'ModifiedMaxPool2DQuantizeConfig': ModifiedMaxPool2DQuantizeConfig},
                    {'ModifiedMaxPool2D_1QuantizeConfig': ModifiedMaxPool2D_1QuantizeConfig},
                    {'ModifiedMaxPool2D_2QuantizeConfig': ModifiedMaxPool2D_2QuantizeConfig},
                    {'ModifiedFlattenQuantizeConfig': ModifiedFlattenQuantizeConfig},
                    {'ModifiedDropoutQuantizeConfig': ModifiedDropoutQuantizeConfig},
                    {'ModifiedDenseQuantizeConfig': ModifiedDenseQuantizeConfig},
                    {'ModifiedDense_1QuantizeConfig': ModifiedDense_1QuantizeConfig}):
    quant_aware_model = tfmot.quantization.keras.quantize_apply(annotated_model4)
    
#Quantizing Dropout   
annotated_model5= tf.keras.models.clone_model(
    quant_aware_model,
    clone_function=apply_quantization_to_layer_Dropout,
)     
    
with quantize_scope({'ModifiedConv2DQuantizeConfig': ModifiedConv2DQuantizeConfig},
                    {'ModifiedConv2D_1QuantizeConfig': ModifiedConv2D_1QuantizeConfig},
                    {'ModifiedConv2D_2QuantizeConfig': ModifiedConv2D_2QuantizeConfig},
                    {'ModifiedActivationQuantizeConfig': ModifiedActivationQuantizeConfig},
                    {'ModifiedActivation_1QuantizeConfig': ModifiedActivation_1QuantizeConfig},
                    {'ModifiedActivation_2QuantizeConfig': ModifiedActivation_2QuantizeConfig},
                    {'ModifiedMaxPool2DQuantizeConfig': ModifiedMaxPool2DQuantizeConfig},
                    {'ModifiedMaxPool2D_1QuantizeConfig': ModifiedMaxPool2D_1QuantizeConfig},
                    {'ModifiedMaxPool2D_2QuantizeConfig': ModifiedMaxPool2D_2QuantizeConfig},
                    {'ModifiedFlattenQuantizeConfig': ModifiedFlattenQuantizeConfig},
                    {'ModifiedDropoutQuantizeConfig': ModifiedDropoutQuantizeConfig},
                    {'ModifiedDenseQuantizeConfig': ModifiedDenseQuantizeConfig},
                    {'ModifiedDense_1QuantizeConfig': ModifiedDense_1QuantizeConfig}):
    quant_aware_model = tfmot.quantization.keras.quantize_apply(annotated_model5)
    
#Quantizing Dense   
annotated_model6= tf.keras.models.clone_model(
    quant_aware_model,
    clone_function=apply_quantization_to_layer_Dense,
)     
    
with quantize_scope({'ModifiedConv2DQuantizeConfig': ModifiedConv2DQuantizeConfig},
                    {'ModifiedConv2D_1QuantizeConfig': ModifiedConv2D_1QuantizeConfig},
                    {'ModifiedConv2D_2QuantizeConfig': ModifiedConv2D_2QuantizeConfig},
                    {'ModifiedActivationQuantizeConfig': ModifiedActivationQuantizeConfig},
                    {'ModifiedActivation_1QuantizeConfig': ModifiedActivation_1QuantizeConfig},
                    {'ModifiedActivation_2QuantizeConfig': ModifiedActivation_2QuantizeConfig},
                    {'ModifiedMaxPool2DQuantizeConfig': ModifiedMaxPool2DQuantizeConfig},
                    {'ModifiedMaxPool2D_1QuantizeConfig': ModifiedMaxPool2D_1QuantizeConfig},
                    {'ModifiedMaxPool2D_2QuantizeConfig': ModifiedMaxPool2D_2QuantizeConfig},
                    {'ModifiedFlattenQuantizeConfig': ModifiedFlattenQuantizeConfig},
                    {'ModifiedDropoutQuantizeConfig': ModifiedDropoutQuantizeConfig},
                    {'ModifiedDenseQuantizeConfig': ModifiedDenseQuantizeConfig},
                    {'ModifiedDense_1QuantizeConfig': ModifiedDense_1QuantizeConfig}):
    quant_aware_model = tfmot.quantization.keras.quantize_apply(annotated_model6)    
    
    
quant_aware_model.summary()

#Compiling the quantized model
sgd = tf.keras.optimizers.SGD(lr=0.01, decay=1e-5, momentum=0.9, nesterov=True)
optimizer = sgd
   
quant_aware_model.compile(optimizer=optimizer,
                      loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                      metrics=['accuracy'])


#TrainingTheQuantizedModel

LEARNING_RATE = 0.01
ITERATIONS = 50
BATCH_SIZE = 64
DISPLAY_STEP = 1
CLASSES = 7
CHANNELS = 1
IMAGE_SIZE = 96
N_INPUT = IMAGE_SIZE * IMAGE_SIZE
DROPOUT = 0.5

train_dir = os.path.join(Thepath, 'train')
val_dir = os.path.join(Thepath, 'val')

image_gen_train = ImageDataGenerator(rescale=1./255, 
                                     featurewise_center=False,
                                     featurewise_std_normalization=False,
                                     rotation_range=10,
                                     width_shift_range=0.1,
                                     height_shift_range=0.1,
                                     zoom_range=.1,
                                     horizontal_flip=True)

train_data_gen = image_gen_train.flow_from_directory(
                                                batch_size=BATCH_SIZE,
                                                directory=train_dir,
                                                shuffle=True,
                                                target_size=(IMAGE_SIZE,IMAGE_SIZE),
                                                class_mode='sparse'
                                                )

image_gen_val = ImageDataGenerator(rescale=1./255) 

val_data_gen = image_gen_val.flow_from_directory(batch_size=BATCH_SIZE,
                                                 directory=val_dir,
                                                 target_size=(IMAGE_SIZE, IMAGE_SIZE),
                                                 class_mode='sparse')


checkpoint = ModelCheckpoint('lastchance.h5', monitor='val_accuracy', verbose=1,
    save_best_only=True, mode='auto', period=1)
quant_checkpoint = ModelCheckpoint('New-Quantized-Vizards-3332242.h5', monitor='val_accuracy', verbose=1,
    save_best_only=True, mode='auto', period=1)

history = pre_trained_model.fit(
    train_data_gen,
    steps_per_epoch=int(np.ceil(train_data_gen.n / float(BATCH_SIZE))),
    epochs=10,
    validation_data=val_data_gen,
    validation_steps=int(np.ceil(val_data_gen.n / float(BATCH_SIZE))),
    callbacks=[checkpoint]
)

history = quant_aware_model.fit(
    train_data_gen,
    steps_per_epoch=int(np.ceil(train_data_gen.n / float(BATCH_SIZE))),
    epochs=850,
    validation_data=val_data_gen,
    validation_steps=int(np.ceil(val_data_gen.n / float(BATCH_SIZE))),
    callbacks=[quant_checkpoint]    
)


pre_trained_model_accuracy = pre_trained_model.evaluate_generator(val_data_gen)
quant_aware_model_accuracy = quant_aware_model.evaluate_generator(val_data_gen)

print('Model accuracy:', pre_trained_model_accuracy[1])
print('Quantized Model accuracy:', quant_aware_model_accuracy[1])
# Out:
# conv2d
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 92, 92, 64)        4864
# _________________________________________________________________
# activation (Activation)      (None, 92, 92, 64)        0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 46, 46, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 42, 42, 128)       204928
# _________________________________________________________________
# activation_1 (Activation)    (None, 42, 42, 128)       0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 21, 21, 128)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 17, 17, 256)       819456
# _________________________________________________________________
# activation_2 (Activation)    (None, 17, 17, 256)       0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 16384)             0
# _________________________________________________________________
# dropout (Dropout)            (None, 16384)             0
# _________________________________________________________________
# dense (Dense)                (None, 300)               4915500
# _________________________________________________________________
# dense_1 (Dense)              (None, 7)                 2107
# =================================================================
# Total params: 5,946,855
# Trainable params: 5,946,855
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# quant_conv2d (QuantizeWrappe (None, 92, 92, 64)        4869
# _________________________________________________________________
# quant_activation (QuantizeWr (None, 92, 92, 64)        5
# _________________________________________________________________
# quant_max_pooling2d (Quantiz (None, 46, 46, 64)        3
# _________________________________________________________________
# quant_conv2d_1 (QuantizeWrap (None, 42, 42, 128)       204933
# _________________________________________________________________
# quant_activation_1 (Quantize (None, 42, 42, 128)       5
# _________________________________________________________________
# quant_max_pooling2d_1 (Quant (None, 21, 21, 128)       3
# _________________________________________________________________
# quant_conv2d_2 (QuantizeWrap (None, 17, 17, 256)       819461
# _________________________________________________________________
# quant_activation_2 (Quantize (None, 17, 17, 256)       5
# _________________________________________________________________
# quant_max_pooling2d_2 (Quant (None, 8, 8, 256)         3
# _________________________________________________________________
# quant_flatten (QuantizeWrapp (None, 16384)             3
# _________________________________________________________________
# quant_dropout (QuantizeWrapp (None, 16384)             3
# _________________________________________________________________
# quant_dense (QuantizeWrapper (None, 300)               4915507
# _________________________________________________________________
# quant_dense_1 (QuantizeWrapp (None, 7)                 2114
# =================================================================
# Total params: 5,946,914
# Trainable params: 5,946,855
# Non-trainable params: 59
# _________________________________________________________________
# Found 260 images belonging to 7 classes.
# Found 67 images belonging to 7 classes.
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of samples seen.
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of samples seen.
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 5 steps, validate for 2 steps
# Epoch 1/10
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0059 - accuracy: 1.0000
# Epoch 00001: val_accuracy improved from -inf to 0.94030, saving model to lastchance.h5
# 5/5 [==============================] - 3s 607ms/step - loss: 0.0151 - accuracy: 0.9962 - val_loss: 0.1428 - val_accuracy: 0.9403
# Epoch 2/10
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0054 - accuracy: 0.9949
# Epoch 00002: val_accuracy did not improve from 0.94030
# 5/5 [==============================] - 2s 457ms/step - loss: 0.0088 - accuracy: 0.9962 - val_loss: 0.1858 - val_accuracy: 0.9254
# Epoch 3/10
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0051 - accuracy: 1.0000
# Epoch 00003: val_accuracy did not improve from 0.94030
# 5/5 [==============================] - 2s 462ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.1519 - val_accuracy: 0.9254
# Epoch 4/10
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0216 - accuracy: 0.9922
# Epoch 00004: val_accuracy did not improve from 0.94030
# 5/5 [==============================] - 2s 438ms/step - loss: 0.0181 - accuracy: 0.9923 - val_loss: 0.1605 - val_accuracy: 0.9403
# Epoch 5/10
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0061 - accuracy: 1.0000
# Epoch 00005: val_accuracy did not improve from 0.94030
# 5/5 [==============================] - 3s 506ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.2053 - val_accuracy: 0.9254
# Epoch 6/10
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0164 - accuracy: 1.0000
# Epoch 00006: val_accuracy did not improve from 0.94030
# 5/5 [==============================] - 2s 424ms/step - loss: 0.0131 - accuracy: 1.0000 - val_loss: 0.1987 - val_accuracy: 0.9104
# Epoch 7/10
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0164 - accuracy: 0.9898
# Epoch 00007: val_accuracy did not improve from 0.94030
# 5/5 [==============================] - 2s 415ms/step - loss: 0.0271 - accuracy: 0.9846 - val_loss: 0.1948 - val_accuracy: 0.9254
# Epoch 8/10
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0105 - accuracy: 1.0000
# Epoch 00008: val_accuracy did not improve from 0.94030
# 5/5 [==============================] - 2s 400ms/step - loss: 0.0084 - accuracy: 1.0000 - val_loss: 0.1696 - val_accuracy: 0.9254
# Epoch 9/10
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0216 - accuracy: 0.9898
# Epoch 00009: val_accuracy did not improve from 0.94030
# 5/5 [==============================] - 3s 531ms/step - loss: 0.0211 - accuracy: 0.9885 - val_loss: 0.2041 - val_accuracy: 0.9254
# Epoch 10/10
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0131 - accuracy: 0.9961
# Epoch 00010: val_accuracy did not improve from 0.94030
# 5/5 [==============================] - 3s 621ms/step - loss: 0.0111 - accuracy: 0.9962 - val_loss: 0.2083 - val_accuracy: 0.9254
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 5 steps, validate for 2 steps
# Epoch 1/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1276
# Epoch 00001: val_accuracy improved from -inf to 0.13433, saving model to New-Quantized-Vizards-3332242.h5
# 5/5 [==============================] - 6s 1s/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 2/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1367
# Epoch 00002: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 469ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 3/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1429
# Epoch 00003: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 429ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 4/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1367
# Epoch 00004: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 438ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 5/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1276
# Epoch 00005: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 431ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 6/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1429
# Epoch 00006: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 419ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 7/850
# 3/5 [=================>............] - ETA: 0s - loss: 1.9459 - accuracy: 0.1250
# Epoch 00007: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 402ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 8/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1582
# Epoch 00008: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 440ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 9/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1582
# Epoch 00009: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 423ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 10/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1367
# Epoch 00010: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 413ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 11/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1429
# Epoch 00011: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 397ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 12/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1582
# Epoch 00012: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 410ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 13/850
# 3/5 [=================>............] - ETA: 0s - loss: 1.9459 - accuracy: 0.1250
# Epoch 00013: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 423ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 14/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1367
# Epoch 00014: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 438ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 15/850
# 3/5 [=================>............] - ETA: 0s - loss: 1.9459 - accuracy: 0.1250
# Epoch 00015: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 402ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 16/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1276
# Epoch 00016: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 418ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 17/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1429
# Epoch 00017: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 411ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 18/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1429
# Epoch 00018: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 406ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 19/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1276
# Epoch 00019: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 437ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 20/850
# 3/5 [=================>............] - ETA: 0s - loss: 1.9459 - accuracy: 0.1250
# Epoch 00020: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 396ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 21/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1367
# Epoch 00021: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 411ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 22/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1367
# Epoch 00022: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 393ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 23/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1276
# Epoch 00023: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 466ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 24/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1276
# Epoch 00024: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 419ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 25/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1367
# Epoch 00025: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 420ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 26/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1276
# Epoch 00026: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 403ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 27/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1429
# Epoch 00027: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 438ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 28/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1276
# Epoch 00028: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 414ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 29/850
# 3/5 [=================>............] - ETA: 0s - loss: 1.9459 - accuracy: 0.1250
# Epoch 00029: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 411ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 30/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1582
# Epoch 00030: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 422ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 31/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1276
# Epoch 00031: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 401ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 32/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1367
# Epoch 00032: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 415ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 33/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1429
# Epoch 00033: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 437ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 34/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1429
# Epoch 00034: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 401ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 35/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1276
# Epoch 00035: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 408ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 36/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1276
# Epoch 00036: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 411ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 37/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1582
# Epoch 00037: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 440ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 38/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1276
# Epoch 00038: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 409ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 39/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1429
# Epoch 00039: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 401ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 40/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1276
# Epoch 00040: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 403ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 41/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1367
# Epoch 00041: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 413ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 42/850
# 3/5 [=================>............] - ETA: 0s - loss: 1.9459 - accuracy: 0.1406
# Epoch 00042: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 444ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 43/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1367
# Epoch 00043: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 430ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 44/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1429
# Epoch 00044: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 393ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 45/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1582
# Epoch 00045: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 3s 573ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 46/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1367
# Epoch 00046: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 411ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 47/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1276
# Epoch 00047: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 419ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 48/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1367
# Epoch 00048: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 435ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 49/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1276
# Epoch 00049: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 407ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 50/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1582
# Epoch 00050: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 404ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 51/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1276
# Epoch 00051: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 409ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 52/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1276
# Epoch 00052: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 436ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 53/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1367
# Epoch 00053: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 425ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 54/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1276
# Epoch 00054: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 391ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 55/850
# 3/5 [=================>............] - ETA: 0s - loss: 1.9459 - accuracy: 0.1250
# Epoch 00055: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 393ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 56/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1276
# Epoch 00056: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 437ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 57/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1367
# Epoch 00057: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 406ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 58/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1367
# Epoch 00058: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 460ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 59/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1429
# Epoch 00059: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 422ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 60/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1276
# Epoch 00060: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 409ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 61/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1367
# Epoch 00061: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 422ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 62/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1429
# Epoch 00062: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 413ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 63/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1429
# Epoch 00063: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 397ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 64/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1276
# Epoch 00064: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 370ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 65/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1367
# Epoch 00065: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 426ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 66/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1367
# Epoch 00066: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 426ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 67/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1429
# Epoch 00067: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 403ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 68/850
# 3/5 [=================>............] - ETA: 0s - loss: 1.9459 - accuracy: 0.1406
# Epoch 00068: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 411ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 69/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1276
# Epoch 00069: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 419ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 70/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1367
# Epoch 00070: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 420ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 71/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1582
# Epoch 00071: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 410ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 72/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1582
# Epoch 00072: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 414ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 73/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1276
# Epoch 00073: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 429ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 74/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1367
# Epoch 00074: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 488ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 75/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1276
# Epoch 00075: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 417ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 76/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1276
# Epoch 00076: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 409ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 77/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1582
# Epoch 00077: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 421ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 78/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1276
# Epoch 00078: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 407ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 79/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1429
# Epoch 00079: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 431ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 80/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1429
# Epoch 00080: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 405ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 81/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1276
# Epoch 00081: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 419ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 82/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1276
# Epoch 00082: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 407ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 83/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1276
# Epoch 00083: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 430ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 84/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1276
# Epoch 00084: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 426ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 85/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1582
# Epoch 00085: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 403ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 86/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1582
# Epoch 00086: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 404ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 87/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1276
# Epoch 00087: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 424ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 88/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1276
# Epoch 00088: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 405ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 89/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1367
# Epoch 00089: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 419ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 90/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1367
# Epoch 00090: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 427ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 91/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1429
# Epoch 00091: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 405ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 92/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1429
# Epoch 00092: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 416ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 93/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1367
# Epoch 00093: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 418ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 94/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1367
# Epoch 00094: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 408ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 95/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1582
# Epoch 00095: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 406ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 96/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1276
# Epoch 00096: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 412ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 97/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1276
# Epoch 00097: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 411ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 98/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1276
# Epoch 00098: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 409ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 99/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1276
# Epoch 00099: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 430ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 100/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1276
# Epoch 00100: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 406ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 101/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1276
# Epoch 00101: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 412ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 102/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1367
# Epoch 00102: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 421ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 103/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1429
# Epoch 00103: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 463ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 104/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1582
# Epoch 00104: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 407ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 105/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1276
# Epoch 00105: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 404ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 106/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1276
# Epoch 00106: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 408ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 107/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1367
# Epoch 00107: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 440ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 108/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1367
# Epoch 00108: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 406ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 109/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1276
# Epoch 00109: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 408ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 110/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1276
# Epoch 00110: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 413ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 111/850
# 3/5 [=================>............] - ETA: 0s - loss: 1.9459 - accuracy: 0.1562
# Epoch 00111: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 421ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 112/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1276
# Epoch 00112: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 410ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 113/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1276
# Epoch 00113: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 400ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 114/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1429
# Epoch 00114: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 421ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 115/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1276
# Epoch 00115: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 391ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 116/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1429
# Epoch 00116: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 395ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 117/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1276
# Epoch 00117: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 440ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 118/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1582
# Epoch 00118: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 453ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 119/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1276
# Epoch 00119: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 434ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 120/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1367
# Epoch 00120: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 421ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 121/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1276
# Epoch 00121: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 402ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 122/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1582
# Epoch 00122: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 424ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 123/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1276
# Epoch 00123: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 414ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 124/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1367
# Epoch 00124: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 417ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 125/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1367
# Epoch 00125: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 407ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 126/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1276
# Epoch 00126: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 399ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 127/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1582
# Epoch 00127: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 430ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 128/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1582
# Epoch 00128: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 437ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 129/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1582
# Epoch 00129: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 424ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 130/850
# 3/5 [=================>............] - ETA: 0s - loss: 1.9459 - accuracy: 0.1406
# Epoch 00130: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 435ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 131/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1276
# Epoch 00131: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 396ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 132/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1429
# Epoch 00132: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 409ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 133/850
# 3/5 [=================>............] - ETA: 0s - loss: 1.9459 - accuracy: 0.1406
# Epoch 00133: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 417ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 134/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1276
# Epoch 00134: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 406ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 135/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1429
# Epoch 00135: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 406ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 136/850
# 3/5 [=================>............] - ETA: 0s - loss: 1.9459 - accuracy: 0.1250
# Epoch 00136: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 411ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 137/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1276
# Epoch 00137: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 408ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 138/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1582
# Epoch 00138: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 410ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 139/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1276
# Epoch 00139: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 404ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 140/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1276
# Epoch 00140: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 426ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 141/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1429
# Epoch 00141: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 416ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 142/850
# 3/5 [=================>............] - ETA: 0s - loss: 1.9459 - accuracy: 0.1250
# Epoch 00142: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 415ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 143/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1276
# Epoch 00143: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 413ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 144/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1276
# Epoch 00144: val_accuracy did not improve from 0.13433
# 5/5 [==============================] - 2s 492ms/step - loss: 1.9459 - accuracy: 0.1385 - val_loss: 1.9459 - val_accuracy: 0.1343
# Epoch 145/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9459 - accuracy: 0.1429
# Epoch 00145: val_accuracy did not improve from 0.13433
# ...
# 5/5 [==============================] - 2s 417ms/step - loss: 1.9105 - accuracy: 0.2154 - val_loss: 1.9018 - val_accuracy: 0.2090
# Epoch 795/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.8877 - accuracy: 0.2143
# Epoch 00795: val_accuracy did not improve from 0.91045
# 5/5 [==============================] - 2s 411ms/step - loss: 1.9109 - accuracy: 0.2154 - val_loss: 1.9018 - val_accuracy: 0.2090
# Epoch 796/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.8792 - accuracy: 0.2245
# Epoch 00796: val_accuracy did not improve from 0.91045
# 5/5 [==============================] - 2s 419ms/step - loss: 1.9109 - accuracy: 0.2154 - val_loss: 1.9018 - val_accuracy: 0.2090
# Epoch 797/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.8876 - accuracy: 0.2143
# Epoch 00797: val_accuracy did not improve from 0.91045
# 5/5 [==============================] - 2s 416ms/step - loss: 1.9109 - accuracy: 0.2154 - val_loss: 1.9018 - val_accuracy: 0.2090
# Epoch 798/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.8786 - accuracy: 0.2245
# Epoch 00798: val_accuracy did not improve from 0.91045
# 5/5 [==============================] - 2s 399ms/step - loss: 1.9104 - accuracy: 0.2154 - val_loss: 1.9017 - val_accuracy: 0.2090
# Epoch 799/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.8998 - accuracy: 0.1990
# Epoch 00799: val_accuracy did not improve from 0.91045
# 5/5 [==============================] - 2s 400ms/step - loss: 1.9100 - accuracy: 0.2154 - val_loss: 1.9017 - val_accuracy: 0.2090
# Epoch 800/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.8861 - accuracy: 0.2143
# Epoch 00800: val_accuracy did not improve from 0.91045
# 5/5 [==============================] - 2s 416ms/step - loss: 1.9095 - accuracy: 0.2154 - val_loss: 1.9017 - val_accuracy: 0.2090
# Epoch 801/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9628 - accuracy: 0.2109
# Epoch 00801: val_accuracy did not improve from 0.91045
# 5/5 [==============================] - 2s 395ms/step - loss: 1.9099 - accuracy: 0.2154 - val_loss: 1.9017 - val_accuracy: 0.2090
# Epoch 802/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.8790 - accuracy: 0.2245
# Epoch 00802: val_accuracy did not improve from 0.91045
# 5/5 [==============================] - 2s 398ms/step - loss: 1.9107 - accuracy: 0.2154 - val_loss: 1.9016 - val_accuracy: 0.2090
# Epoch 803/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.8865 - accuracy: 0.2143
# Epoch 00803: val_accuracy did not improve from 0.91045
# 5/5 [==============================] - 2s 413ms/step - loss: 1.9099 - accuracy: 0.2154 - val_loss: 1.9016 - val_accuracy: 0.2090
# Epoch 804/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9608 - accuracy: 0.2109
# Epoch 00804: val_accuracy did not improve from 0.91045
# 5/5 [==============================] - 2s 454ms/step - loss: 1.9082 - accuracy: 0.2154 - val_loss: 1.8996 - val_accuracy: 0.2090
# Epoch 805/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.8872 - accuracy: 0.2143
# Epoch 00805: val_accuracy did not improve from 0.91045
# 5/5 [==============================] - 2s 406ms/step - loss: 1.9066 - accuracy: 0.2192 - val_loss: 1.8975 - val_accuracy: 0.2090
# Epoch 806/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9577 - accuracy: 0.2109
# Epoch 00806: val_accuracy did not improve from 0.91045
# 5/5 [==============================] - 2s 424ms/step - loss: 1.9058 - accuracy: 0.2154 - val_loss: 1.8704 - val_accuracy: 0.2090
# Epoch 807/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9476 - accuracy: 0.2148
# Epoch 00807: val_accuracy did not improve from 0.91045
# 5/5 [==============================] - 2s 418ms/step - loss: 1.8974 - accuracy: 0.2192 - val_loss: 1.8703 - val_accuracy: 0.2090
# Epoch 808/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.8526 - accuracy: 0.2245
# Epoch 00808: val_accuracy did not improve from 0.91045
# 5/5 [==============================] - 2s 413ms/step - loss: 1.8699 - accuracy: 0.2423 - val_loss: 1.8265 - val_accuracy: 0.2836
# Epoch 809/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.8906 - accuracy: 0.2551
# Epoch 00809: val_accuracy did not improve from 0.91045
# 5/5 [==============================] - 2s 410ms/step - loss: 1.8894 - accuracy: 0.2654 - val_loss: 1.8486 - val_accuracy: 0.2687
# Epoch 810/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.8072 - accuracy: 0.2602
# Epoch 00810: val_accuracy did not improve from 0.91045
# 5/5 [==============================] - 2s 425ms/step - loss: 1.8296 - accuracy: 0.2577 - val_loss: 1.8675 - val_accuracy: 0.2836
# Epoch 811/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.8487 - accuracy: 0.2449
# Epoch 00811: val_accuracy did not improve from 0.91045
# 5/5 [==============================] - 2s 410ms/step - loss: 1.8565 - accuracy: 0.2577 - val_loss: 1.8235 - val_accuracy: 0.2836
# Epoch 812/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9149 - accuracy: 0.2245
# Epoch 00812: val_accuracy did not improve from 0.91045
# 5/5 [==============================] - 2s 425ms/step - loss: 1.9346 - accuracy: 0.2154 - val_loss: 1.9014 - val_accuracy: 0.2090
# Epoch 813/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9632 - accuracy: 0.2109
# Epoch 00813: val_accuracy did not improve from 0.91045
# 5/5 [==============================] - 2s 394ms/step - loss: 1.9104 - accuracy: 0.2154 - val_loss: 1.9014 - val_accuracy: 0.2090
# Epoch 814/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.8788 - accuracy: 0.2245
# Epoch 00814: val_accuracy did not improve from 0.91045
# 5/5 [==============================] - 2s 394ms/step - loss: 1.9104 - accuracy: 0.2154 - val_loss: 1.9013 - val_accuracy: 0.2090
# Epoch 815/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.8999 - accuracy: 0.1990
# Epoch 00815: val_accuracy did not improve from 0.91045
# 5/5 [==============================] - 2s 396ms/step - loss: 1.9104 - accuracy: 0.2154 - val_loss: 1.9013 - val_accuracy: 0.2090
# Epoch 816/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.8788 - accuracy: 0.2245
# Epoch 00816: val_accuracy did not improve from 0.91045
# 5/5 [==============================] - 2s 436ms/step - loss: 1.9103 - accuracy: 0.2154 - val_loss: 1.9013 - val_accuracy: 0.2090
# Epoch 817/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9631 - accuracy: 0.2109
# Epoch 00817: val_accuracy did not improve from 0.91045
# 5/5 [==============================] - 2s 457ms/step - loss: 1.9103 - accuracy: 0.2154 - val_loss: 1.9013 - val_accuracy: 0.2090
# Epoch 818/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9630 - accuracy: 0.2109
# Epoch 00818: val_accuracy did not improve from 0.91045
# 5/5 [==============================] - 2s 436ms/step - loss: 1.9103 - accuracy: 0.2154 - val_loss: 1.9012 - val_accuracy: 0.2090
# Epoch 819/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.8998 - accuracy: 0.1990
# Epoch 00819: val_accuracy did not improve from 0.91045
# 5/5 [==============================] - 2s 423ms/step - loss: 1.9102 - accuracy: 0.2154 - val_loss: 1.9012 - val_accuracy: 0.2090
# Epoch 820/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.8746 - accuracy: 0.2296
# Epoch 00820: val_accuracy did not improve from 0.91045
# 5/5 [==============================] - 2s 407ms/step - loss: 1.9102 - accuracy: 0.2154 - val_loss: 1.9012 - val_accuracy: 0.2090
# Epoch 821/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.8787 - accuracy: 0.2245
# Epoch 00821: val_accuracy did not improve from 0.91045
# 5/5 [==============================] - 2s 396ms/step - loss: 1.9102 - accuracy: 0.2154 - val_loss: 1.9012 - val_accuracy: 0.2090
# Epoch 822/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9628 - accuracy: 0.2109
# Epoch 00822: val_accuracy did not improve from 0.91045
# 5/5 [==============================] - 2s 435ms/step - loss: 1.9102 - accuracy: 0.2154 - val_loss: 1.9011 - val_accuracy: 0.2090
# Epoch 823/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.8997 - accuracy: 0.1990
# Epoch 00823: val_accuracy did not improve from 0.91045
# 5/5 [==============================] - 2s 411ms/step - loss: 1.9101 - accuracy: 0.2154 - val_loss: 1.9011 - val_accuracy: 0.2090
# Epoch 824/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.8997 - accuracy: 0.1990
# Epoch 00824: val_accuracy did not improve from 0.91045
# 5/5 [==============================] - 2s 399ms/step - loss: 1.9101 - accuracy: 0.2154 - val_loss: 1.9011 - val_accuracy: 0.2090
# Epoch 825/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.8745 - accuracy: 0.2296
# Epoch 00825: val_accuracy did not improve from 0.91045
# 5/5 [==============================] - 2s 399ms/step - loss: 1.9101 - accuracy: 0.2154 - val_loss: 1.9011 - val_accuracy: 0.2090
# Epoch 826/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9626 - accuracy: 0.2109
# Epoch 00826: val_accuracy did not improve from 0.91045
# 5/5 [==============================] - 2s 409ms/step - loss: 1.9101 - accuracy: 0.2154 - val_loss: 1.9011 - val_accuracy: 0.2090
# Epoch 827/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.8787 - accuracy: 0.2245
# Epoch 00827: val_accuracy did not improve from 0.91045
# 5/5 [==============================] - 2s 422ms/step - loss: 1.9100 - accuracy: 0.2154 - val_loss: 1.9010 - val_accuracy: 0.2090
# Epoch 828/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9626 - accuracy: 0.2109
# Epoch 00828: val_accuracy did not improve from 0.91045
# 5/5 [==============================] - 2s 433ms/step - loss: 1.9100 - accuracy: 0.2154 - val_loss: 1.9010 - val_accuracy: 0.2090
# Epoch 829/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.8870 - accuracy: 0.2143
# Epoch 00829: val_accuracy did not improve from 0.91045
# 5/5 [==============================] - 2s 410ms/step - loss: 1.9100 - accuracy: 0.2154 - val_loss: 1.9010 - val_accuracy: 0.2090
# Epoch 830/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.8744 - accuracy: 0.2296
# Epoch 00830: val_accuracy did not improve from 0.91045
# 5/5 [==============================] - 2s 417ms/step - loss: 1.9100 - accuracy: 0.2154 - val_loss: 1.9010 - val_accuracy: 0.2090
# Epoch 831/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9624 - accuracy: 0.2109
# Epoch 00831: val_accuracy did not improve from 0.91045
# 5/5 [==============================] - 2s 413ms/step - loss: 1.9099 - accuracy: 0.2154 - val_loss: 1.9009 - val_accuracy: 0.2090
# Epoch 832/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.8995 - accuracy: 0.1990
# Epoch 00832: val_accuracy did not improve from 0.91045
# 5/5 [==============================] - 2s 398ms/step - loss: 1.9099 - accuracy: 0.2154 - val_loss: 1.9009 - val_accuracy: 0.2090
# Epoch 833/850
# 3/5 [=================>............] - ETA: 0s - loss: 1.9651 - accuracy: 0.2083
# Epoch 00833: val_accuracy did not improve from 0.91045
# 5/5 [==============================] - 2s 395ms/step - loss: 1.9099 - accuracy: 0.2154 - val_loss: 1.9009 - val_accuracy: 0.2090
# Epoch 834/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.8786 - accuracy: 0.2245
# Epoch 00834: val_accuracy did not improve from 0.91045
# 5/5 [==============================] - 2s 413ms/step - loss: 1.9099 - accuracy: 0.2154 - val_loss: 1.9009 - val_accuracy: 0.2090
# Epoch 835/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.8785 - accuracy: 0.2245
# Epoch 00835: val_accuracy did not improve from 0.91045
# 5/5 [==============================] - 2s 401ms/step - loss: 1.9098 - accuracy: 0.2154 - val_loss: 1.9009 - val_accuracy: 0.2090
# Epoch 836/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.8869 - accuracy: 0.2143
# Epoch 00836: val_accuracy did not improve from 0.91045
# 5/5 [==============================] - 2s 413ms/step - loss: 1.9098 - accuracy: 0.2154 - val_loss: 1.9008 - val_accuracy: 0.2090
# Epoch 837/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9622 - accuracy: 0.2109
# Epoch 00837: val_accuracy did not improve from 0.91045
# 5/5 [==============================] - 2s 423ms/step - loss: 1.9098 - accuracy: 0.2154 - val_loss: 1.9008 - val_accuracy: 0.2090
# Epoch 838/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.8994 - accuracy: 0.1990
# Epoch 00838: val_accuracy did not improve from 0.91045
# 5/5 [==============================] - 2s 491ms/step - loss: 1.9098 - accuracy: 0.2154 - val_loss: 1.9008 - val_accuracy: 0.2090
# Epoch 839/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.8785 - accuracy: 0.2245
# Epoch 00839: val_accuracy did not improve from 0.91045
# 5/5 [==============================] - 2s 389ms/step - loss: 1.9097 - accuracy: 0.2154 - val_loss: 1.9008 - val_accuracy: 0.2090
# Epoch 840/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.8743 - accuracy: 0.2296
# Epoch 00840: val_accuracy did not improve from 0.91045
# 5/5 [==============================] - 2s 395ms/step - loss: 1.9097 - accuracy: 0.2154 - val_loss: 1.9008 - val_accuracy: 0.2090
# Epoch 841/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.8785 - accuracy: 0.2245
# Epoch 00841: val_accuracy did not improve from 0.91045
# 5/5 [==============================] - 2s 379ms/step - loss: 1.9097 - accuracy: 0.2154 - val_loss: 1.9007 - val_accuracy: 0.2090
# Epoch 842/850
# 3/5 [=================>............] - ETA: 0s - loss: 1.9481 - accuracy: 0.2240
# Epoch 00842: val_accuracy did not improve from 0.91045
# 5/5 [==============================] - 2s 435ms/step - loss: 1.9097 - accuracy: 0.2154 - val_loss: 1.9007 - val_accuracy: 0.2090
# Epoch 843/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.8993 - accuracy: 0.1990
# Epoch 00843: val_accuracy did not improve from 0.91045
# 5/5 [==============================] - 2s 423ms/step - loss: 1.9097 - accuracy: 0.2154 - val_loss: 1.9007 - val_accuracy: 0.2090
# Epoch 844/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.8784 - accuracy: 0.2245
# Epoch 00844: val_accuracy did not improve from 0.91045
# 5/5 [==============================] - 2s 407ms/step - loss: 1.9096 - accuracy: 0.2154 - val_loss: 1.9007 - val_accuracy: 0.2090
# Epoch 845/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.8993 - accuracy: 0.1990
# Epoch 00845: val_accuracy did not improve from 0.91045
# 5/5 [==============================] - 2s 399ms/step - loss: 1.9096 - accuracy: 0.2154 - val_loss: 1.9007 - val_accuracy: 0.2090
# Epoch 846/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.8993 - accuracy: 0.1990
# Epoch 00846: val_accuracy did not improve from 0.91045
# 5/5 [==============================] - 2s 423ms/step - loss: 1.9096 - accuracy: 0.2154 - val_loss: 1.9006 - val_accuracy: 0.2090
# Epoch 847/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.8784 - accuracy: 0.2245
# Epoch 00847: val_accuracy did not improve from 0.91045
# 5/5 [==============================] - 2s 398ms/step - loss: 1.9096 - accuracy: 0.2154 - val_loss: 1.9006 - val_accuracy: 0.2090
# Epoch 848/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.9617 - accuracy: 0.2109
# Epoch 00848: val_accuracy did not improve from 0.91045
# 5/5 [==============================] - 2s 405ms/step - loss: 1.9095 - accuracy: 0.2154 - val_loss: 1.9006 - val_accuracy: 0.2090
# Epoch 849/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.8742 - accuracy: 0.2296
# Epoch 00849: val_accuracy did not improve from 0.91045
# 5/5 [==============================] - 2s 426ms/step - loss: 1.9095 - accuracy: 0.2154 - val_loss: 1.9006 - val_accuracy: 0.2090
# Epoch 850/850
# 4/5 [=======================>......] - ETA: 0s - loss: 1.8784 - accuracy: 0.2245
# Epoch 00850: val_accuracy did not improve from 0.91045
# 5/5 [==============================] - 2s 421ms/step - loss: 1.9095 - accuracy: 0.2154 - val_loss: 1.9006 - val_accuracy: 0.2090
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Model accuracy: 0.92537314
# Quantized Model accuracy: 0.20895523
